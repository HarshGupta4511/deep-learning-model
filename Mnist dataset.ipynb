# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
(x_train,y_train) , (x_test,y_test) = tf.keras.datasets.mnist.load_data()

# %%
print(f"The size of train dataset is {x_train.shape}")
# Out:
# The size of train dataset is (60000, 28, 28)

# %%
print(f"The size of test dataset is {x_test.shape}")
# Out:
# The size of test dataset is (10000, 28, 28)

# %%
plt.figure(figsize=(20,2))
for i in range (10,20):
    plt.subplot(1,10,i+1-10) #row , columns , position
    plt.imshow(x_train[i] ,cmap='gray')
    plt.axis('off')
    plt.title(str(y_train[i]))
    plt.tight_layout()
